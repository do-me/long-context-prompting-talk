# %%
import pandas as pd 
df = pd.read_excel("https://github.com/do-me/SDG/raw/refs/heads/main/SDG_Target_Indicator_UNSD_2023.xlsx")
df
# Out:
#      SDGNumber                    SDGTitle TargetsNumber  \
# 0            1                  No Poverty           1.1
# 1            1                  No Poverty           1.2
# 2            1                  No Poverty           1.2
# 3            1                  No Poverty           1.3
# 4            1                  No Poverty           1.4
# ..         ...                         ...           ...
# 244         17  Partnerships for the Goals         17.18
# 245         17  Partnerships for the Goals         17.18
# 246         17  Partnerships for the Goals         17.18
# 247         17  Partnerships for the Goals         17.19
# 248         17  Partnerships for the Goals         17.19
#
#                                                Targets IndicatorsNumber  \
# 0     By 2030, eradicate extreme poverty for all pe...            1.1.1
# 1     By 2030, reduce at least by half the proporti...            1.2.1
# ...

# %%
with open("sdg_indicators.txt", "w") as file:
    for index, row in df.iterrows():
        for col in ["SDGTitle", "IndicatorsNumber", "Indicators"]:
            file.write(f"{str(row[col]).strip()}\n")
        file.write("---\n")
